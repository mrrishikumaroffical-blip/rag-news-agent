# %% [markdown]
# <a href="https://colab.research.google.com/github/mrrishikumaroffical-blip/rag-news-agent/blob/main/Copy_of_RAG_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/mrrishikumaroffical-blip/rag-news-agent.git
# %cd rag-news-agent
# Out:
# Cloning into 'rag-news-agent'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 18 (delta 3), reused 15 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), done.
# Resolving deltas: 100% (3/3), done.
# /content/rag-news-agent

# %%
# !pip install feedparser newspaper3k requests lxml_html_clean

# %%
# !python app/rag/ingest.py
# Out:
# Fetching feed: https://techcrunch.com/feed/
# Downloading: Ethan Thornton is trying to do everything all at once
# Downloading: Ubisoft co-founder Claude Guillemot dies in plane crash
# Downloading: Polymarket reportedly paid creators to post deceptive videos about fake bets
# Downloading: TechCrunch Mobility: A new robotaxi scorecard shows China’s dominance
# Downloading: When the Trump administration cracks down on Anthropic, who benefits?
# Downloading: Beyond Siri: Here are the practical AI features coming to your iPhone in iOS 27
# Downloading: Signal’s Meredith Whittaker wants you to remember that AI chatbots ‘are not your friends’
# Downloading: In the Weights is your new AI-centric vanity search
# Downloading: Founders Fund’s outlier bet on humanely killed fish
# Downloading: Nobel laureate John Jumper is leaving DeepMind for rival Anthropic
# Saved 10 articles to data/raw/articles.json

# %%
import json
with open('data/raw/articles.json') as f:
    articles = json.load(f)

print(f'Total articles: {len(articles)}')
print('---')
for a in articles:
    print(a['title'])
# Out:
# Total articles: 10
# ---
# Ethan Thornton is trying to do everything all at once
# Ubisoft co-founder Claude Guillemot dies in plane crash
# Polymarket reportedly paid creators to post deceptive videos about fake bets
# TechCrunch Mobility: A new robotaxi scorecard shows China’s dominance
# When the Trump administration cracks down on Anthropic, who benefits?
# Beyond Siri: Here are the practical AI features coming to your iPhone in iOS 27
# Signal’s Meredith Whittaker wants you to remember that AI chatbots ‘are not your friends’
# In the Weights is your new AI-centric vanity search
# Founders Fund’s outlier bet on humanely killed fish
# Nobel laureate John Jumper is leaving DeepMind for rival Anthropic
